# %%
# %matplotlib inline

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import statistics

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev,color='maroon',capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.yticks(np.arange(0,60,step=5.0))
# Out:
# ([<matplotlib.axis.YTick at 0x1d7e51ca888>,
#   <matplotlib.axis.YTick at 0x1d7e518e608>,
#   <matplotlib.axis.YTick at 0x1d7e51bf808>,
#   <matplotlib.axis.YTick at 0x1d7e5227388>,
#   <matplotlib.axis.YTick at 0x1d7e522b288>,
#   <matplotlib.axis.YTick at 0x1d7e522f108>,
#   <matplotlib.axis.YTick at 0x1d7e522ff88>,
#   <matplotlib.axis.YTick at 0x1d7e5233488>,
#   <matplotlib.axis.YTick at 0x1d7e52361c8>,
#   <matplotlib.axis.YTick at 0x1d7e5236ec8>,
#   <matplotlib.axis.YTick at 0x1d7e523bc48>,
#   <matplotlib.axis.YTick at 0x1d7e523fac8>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()
